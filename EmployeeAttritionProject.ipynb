# %% [markdown]
# # Employee Attrition

# %% [markdown]
# ### Manahil Aamir - 24441 & Hritika Rai - 24513

# %%
#importing the basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as mano
# %matplotlib inline
import seaborn as sns
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22772\1804142020.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
#read the .csv file
employee = pd.read_csv('EmployeeAttrition.csv')

# %%
employee.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ### Data Wrangling -> Handling Missing Values and Formatting(which includes Outliers too)

# %%
employee.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# mano.matrix(employee)

# %% [markdown]
# Method to print distinct values of any specified column

# %%
def unique(df, column_name):
    # Check if the column exists in the DataFrame
    if column_name not in df.columns:
        print(f"Column '{column_name}' does not exist in the DataFrame.")
        return
    
    # Extract unique values of the specified column
    unique_values = df[column_name].unique()
    return unique_values

# %% [markdown]
# #### Deleting useless columns that have same value throughout dataset

# %%
def drop_column(df, column_name):
    if column_name not in df.columns:
        print(f"Column '{column_name}' does not exist in the DataFrame.")
        return df
    
    return df.drop(columns=[column_name], axis = 1, inplace = True)

# %% [markdown]
# ##### Deleting EmployeeCount

# %%
unique(employee, 'EmployeeCount')
# Out:
# array([1], dtype=int64)

# %%
drop_column(employee, 'EmployeeCount')

# %%
print(employee.columns)
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ##### Deleting Over18

# %%
unique(employee, 'Over18')
# Out:
# array(['Y'], dtype=object)

# %%
drop_column(employee, 'Over18')

# %%
print(employee.columns)
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ##### Deleting StandardHours

# %%
unique(employee, 'StandardHours')
# Out:
# array([80], dtype=int64)

# %%
drop_column(employee, 'StandardHours')

# %%
print(employee.columns)
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# #### Method of mapping column values with description so that it is easie to understand

# %%
def map_values(df, column_name, value_map):
    if column_name not in df.columns:
        print(f"Column '{column_name}' does not exist in the DataFrame.")
        return df

    df[column_name] = df[column_name].map(value_map)

# %% [markdown]
# ##### Handling Education column

# %%
unique(employee, 'Education')
# Out:
# array([2, 1, 4, 3, 5], dtype=int64)

# %%
education_map = {
    1: 'Below College',
    2: 'College',
    3: 'Bachelor',
    4: 'Master',
    5: 'Doctor'
}
map_values(employee, 'Education', education_map)

# %%
unique(employee, 'Education')
# Out:
# array(['College', 'Below College', 'Master', 'Bachelor', 'Doctor'],
#       dtype=object)

# %% [markdown]
# ##### Handling EnvironmentSatisfaction column

# %%
unique(employee, 'EnvironmentSatisfaction')
# Out:
# array([2, 3, 4, 1], dtype=int64)

# %%
environment_satisfaction_map = {
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High'
}
map_values(employee, 'EnvironmentSatisfaction', environment_satisfaction_map)

# %%
unique(employee, 'EnvironmentSatisfaction')
# Out:
# array(['Medium', 'High', 'Very High', 'Low'], dtype=object)

# %% [markdown]
# ##### Handling JobInvolvement column

# %%
unique(employee, 'JobInvolvement')
# Out:
# array([3, 2, 4, 1], dtype=int64)

# %%
job_involvement_map = {
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High'
}
map_values(employee, 'JobInvolvement', job_involvement_map)

# %%
unique(employee, 'JobInvolvement')
# Out:
# array(['High', 'Medium', 'Very High', 'Low'], dtype=object)

# %% [markdown]
# ##### Handling JobSatisfaction column

# %%
unique(employee, 'JobSatisfaction')
# Out:
# array([4, 2, 3, 1], dtype=int64)

# %%
job_satisfaction_map = {
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High'
}
map_values(employee, 'JobSatisfaction', job_satisfaction_map)

# %%
unique(employee, 'JobSatisfaction')
# Out:
# array(['Very High', 'Medium', 'High', 'Low'], dtype=object)

# %% [markdown]
# ##### Handling PerformanceRating column

# %%
unique(employee, 'PerformanceRating')
# Out:
# array([3, 4], dtype=int64)

# %%
performance_rating_map = {
    1: 'Low',
    2: 'Good',
    3: 'Excellent',
    4: 'Outstanding'
}
map_values(employee, 'PerformanceRating', performance_rating_map)

# %%
unique(employee, 'PerformanceRating')
# Out:
# array(['Excellent', 'Outstanding'], dtype=object)

# %% [markdown]
# ##### Handling RelationshipSatisfaction column

# %%
unique(employee, 'RelationshipSatisfaction')
# Out:
# array([1, 4, 2, 3], dtype=int64)

# %%
relationship_satisfaction_map = {
    1: 'Low',
    2: 'Medium',
    3: 'High',
    4: 'Very High'
}
map_values(employee, 'RelationshipSatisfaction', relationship_satisfaction_map)

# %%
unique(employee, 'RelationshipSatisfaction')
# Out:
# array(['Low', 'Very High', 'Medium', 'High'], dtype=object)

# %% [markdown]
# ##### Handling WorkLifeBalance column

# %%
unique(employee, 'WorkLifeBalance')
# Out:
# array([1, 3, 2, 4], dtype=int64)

# %%
work_life_balance_map = {
    1: 'Bad',
    2: 'Good',
    3: 'Better',
    4: 'Best'
}
map_values(employee, 'WorkLifeBalance', work_life_balance_map)

# %%
unique(employee, 'WorkLifeBalance')
# Out:
# array(['Bad', 'Better', 'Good', 'Best'], dtype=object)

# %% [markdown]
# #### Checking that all categorical columns have valid values

# %% [markdown]
# ##### Checking Attrition column

# %%
unique(employee, 'Attrition')
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# ##### Checking BusinessTravel column

# %%
unique(employee, 'BusinessTravel')
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %% [markdown]
# ##### Checking Department column

# %%
unique(employee, 'Department')
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %% [markdown]
# ##### Checking EducationField column

# %%
unique(employee, 'EducationField')
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %% [markdown]
# ##### Checking Gender column

# %%
unique(employee, 'Gender')
# Out:
# array(['Female', 'Male'], dtype=object)

# %% [markdown]
# ##### Checking JobRole column

# %%
unique(employee, 'JobRole')
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %% [markdown]
# ##### Checking MaritalStatus column

# %%
unique(employee, 'MaritalStatus')
# Out:
# array(['Single', 'Married', 'Divorced'], dtype=object)

# %% [markdown]
# ##### Checking OverTime column

# %%
unique(employee, 'OverTime')
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# #### Checking that no major outlier exists in the numerical columns via box plot otherwise treating that accordingly. Also, treating double values where they are supposed to be integers. ALso, where there is trend of outliers showing through histogram that how these outliers are not really different from actual data and they makes sense.

# %%
def create_boxplot(df, column_name):
    # Set style
    sns.set_style("whitegrid")
    
    # Create boxplot
    ax = sns.boxplot(x=df[column_name], color='turquoise', width=0.5)
    
    # Add title
    ax.set_title("Boxplot of " + column_name)
    
    # Set x-label
    ax.set_xlabel(column_name)
    
    # Set y-label
    ax.set_ylabel("Values")
    
    # Calculate and print median and IQR
    median = df[column_name].median()
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)
    IQR = Q3 - Q1
    print("Median:", median)
    print("IQR:", IQR)
    
    # Show plot
    plt.show()

# %%
def round_to_integer(df, column):
    df[column] = df[column].round()

# %%
def create_numerical_histogram(df, column_name, b):
    # Set Seaborn style
    sns.set_style("whitegrid")
    
    # Create histogram
    sns.histplot(df[column_name], bins=b, color='purple', edgecolor='black')
    # Rotate x-axis labels for better readability
    plt.xticks(rotation=45, ha='right')
    plt.gca().xaxis.set_label_coords(0.5, -0.1)
    # Add labels and title
    plt.xlabel(column_name)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column_name}')
    
    # Show plot
    plt.show()

# %%
unique(employee, 'Age')
# Out:
# array([41, 49, 37, 33, 27, 32, 59, 30, 38, 36, 35, 29, 31, 34, 28, 22, 53,
#        24, 21, 42, 44, 46, 39, 43, 50, 26, 48, 55, 45, 56, 23, 51, 40, 54,
#        58, 20, 25, 19, 57, 52, 47, 18, 60], dtype=int64)

# %%
create_boxplot(employee, 'Age')
# Out:
# Median: 36.0
# IQR: 13.0

# %% [markdown]
# No outliers

# %% [markdown]
# ##### Checking DailyRate column

# %%
create_boxplot(employee, 'DailyRate')
# Out:
# Median: 802.0
# IQR: 692.0

# %% [markdown]
# No outliers

# %% [markdown]
# ##### Checking DistanceFromHome column

# %%
create_boxplot(employee, 'DistanceFromHome')
# Out:
# Median: 7.0
# IQR: 12.0

# %% [markdown]
# No outliers

# %% [markdown]
# ##### Checking HourlyRate column

# %%
create_boxplot(employee, 'HourlyRate')
# Out:
# Median: 66.0
# IQR: 35.75

# %% [markdown]
# No outliers

# %% [markdown]
# ##### Checking MonthlyIncome column

# %%
create_boxplot(employee, 'MonthlyIncome')
# Out:
# Median: 4919.0
# IQR: 5468.0

# %%
minimum_monthly_income = employee['MonthlyIncome'].min()
maximum_monthly_income = employee['MonthlyIncome'].max()

print("Minimum Monthly Income:", minimum_monthly_income)
print("Maximum Monthly Income:", maximum_monthly_income)
# Out:
# Minimum Monthly Income: 1009
# Maximum Monthly Income: 19999

# %%
create_numerical_histogram(employee, 'MonthlyIncome', 10)
# Out:
# C:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# In the context of monthly income data, outliers often represent valid extremes rather than errors. These outliers can include high earners, business owners, or individuals with unique financial circumstances. Since income distribution typically forms a continuous range without clear as shown in histogram, removing outliers or imputing them might lead to a loss of valuable information. Furthermore, attempting to treat outliers indiscriminately can distort the statistical analysis.

# %% [markdown]
# ##### Checking MonthlyRate column

# %%
create_boxplot(employee, 'MonthlyRate')
# Out:
# Median: 14235.5
# IQR: 12414.5

# %% [markdown]
# No outliers

# %% [markdown]
# ##### Checking NumCompaniesWorked column

# %%
unique(employee, 'NumCompaniesWorked')
# Out:
# array([8, 1, 6, 9, 0, 4, 5, 2, 7, 3], dtype=int64)

# %%
create_boxplot(employee, 'NumCompaniesWorked')
# Out:
# Median: 2.0
# IQR: 3.0

# %%
create_numerical_histogram(employee, 'NumCompaniesWorked', 9)
# Out:
# C:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# In this context, the outlier is not necessarily an error or incorrect data, but rather an indication of a less common occurrence. It's conceivable that some individuals as represented by histogram may indeed have the capability to work for a high number of companies due to unique circumstances or specialized skills. While this is less common, it is not outside the realm of possibility. Therefore, it might be beneficial to keep this data point. Removing it could lead to a loss of information about these less common cases.

# %% [markdown]
# ##### Checking PercentSalaryHike column

# %%
create_boxplot(employee, 'PercentSalaryHike')
# Out:
# Median: 14.0
# IQR: 6.0

# %% [markdown]
# There is no outlier.

# %% [markdown]
# ##### Checking StockOptionLevel column

# %%
unique(employee, 'StockOptionLevel')
# Out:
# array([0, 1, 3, 2], dtype=int64)

# %%
create_boxplot(employee, 'StockOptionLevel')
# Out:
# Median: 1.0
# IQR: 1.0

# %%
create_numerical_histogram(employee, 'StockOptionLevel', 3)
# Out:
# C:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# In this context, the outlier is not necessarily an error or incorrect data, but rather an indication of a less common occurrence. It represents individuals who have the option to work for three different companies. While this is less common, it is not outside the realm of possibility. Therefore, it might be beneficial to keep this data point. Removing it could lead to a loss of information about these less common cases.

# %% [markdown]
# ##### Checking TotalWorkingYears column

# %%
unique(employee, 'TotalWorkingYears')
# Out:
# array([ 8, 10,  7,  6, 12,  1, 17,  5,  3, 31, 13,  0, 26, 24, 22,  9, 19,
#         2, 23, 14, 15,  4, 29, 28, 21, 25, 20, 11, 16, 37, 38, 30, 40, 18,
#        36, 34, 32, 33, 35, 27], dtype=int64)

# %%
create_boxplot(employee, 'TotalWorkingYears')
# Out:
# Median: 10.0
# IQR: 9.0

# %%
create_numerical_histogram(employee, 'TotalWorkingYears', 10)
# Out:
# C:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# In this context, these outliers are not necessarily errors or incorrect data, but rather indicate less common occurrences. They represent individuals who have worked for a large number of years. While these cases are less common, they are not outside the realm of possibility. Therefore, it might be beneficial to keep these data points.

# %% [markdown]
# ##### Checking TrainingTimesLastYear column

# %%
unique(employee, 'TrainingTimesLastYear')
# Out:
# array([0, 3, 2, 5, 1, 4, 6], dtype=int64)

# %%
round_to_integer(employee, 'TrainingTimesLastYear')
unique(employee, 'TrainingTimesLastYear')
# Out:
# array([0, 3, 2, 5, 1, 4, 6], dtype=int64)

# %%
create_boxplot(employee, 'TrainingTimesLastYear')
# Out:
# Median: 3.0
# IQR: 1.0

# %%
create_numerical_histogram(employee, 'TrainingTimesLastYear', 6)
# Out:
# C:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# In this context, these outliers are not necessarily errors or incorrect data, but rather indicate less common occurrences. They represent individuals who have undergone training either very few or many times in the last year. While these cases are less common, they are not outside the realm of possibility. Therefore, it might be beneficial to keep these data points.

# %% [markdown]
# ##### Checking YearsAtCompany column

# %%
unique(employee, 'YearsAtCompany')
# Out:
# array([ 6, 10,  0,  8,  2,  7,  1,  9,  5,  4, 25,  3, 12, 14, 22, 15, 27,
#        21, 17, 11, 13, 37, 16, 20, 40, 24, 33, 19, 36, 18, 29, 31, 32, 34,
#        26, 30, 23], dtype=int64)

# %%
create_boxplot(employee, 'YearsAtCompany')
# Out:
# Median: 5.0
# IQR: 6.0

# %%
create_numerical_histogram(employee, 'YearsAtCompany', 8)
# Out:
# C:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# In this context, these outliers are not necessarily errors or incorrect data, but rather indicate less common occurrences. They represent individuals who have spent half of there life working in the company. While these cases are less common, they are not outside the realm of possibility. Therefore, it might be beneficial to keep these data points.

# %% [markdown]
# ##### Checking YearsInCurrentRole column

# %%
unique(employee, 'YearsInCurrentRole')
# Out:
# array([ 4,  7,  0,  2,  5,  9,  8,  3,  6, 13,  1, 15, 14, 16, 11, 10, 12,
#        18, 17], dtype=int64)

# %%
round_to_integer(employee, 'YearsInCurrentRole')
unique(employee, 'YearsInCurrentRole')
# Out:
# array([ 4,  7,  0,  2,  5,  9,  8,  3,  6, 13,  1, 15, 14, 16, 11, 10, 12,
#        18, 17], dtype=int64)

# %%
create_boxplot(employee, 'YearsInCurrentRole')
# Out:
# Median: 3.0
# IQR: 5.0

# %%
create_numerical_histogram(employee, 'YearsInCurrentRole', 8)
# Out:
# C:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# In this context, these outliers are not necessarily errors or incorrect data, but rather indicate less common occurrences. They represent individuals who stay in there current role as the dont want to change or are unable to change. While these cases are less common, they are not outside the realm of possibility. Therefore, it might be beneficial to keep these data points.

# %% [markdown]
# ##### Checking YearsSinceLastPromotion column

# %%
unique(employee, 'YearsSinceLastPromotion')
# Out:
# array([ 0,  1,  3,  2,  7,  4,  8,  6,  5, 15,  9, 13, 12, 10, 11, 14],
#       dtype=int64)

# %%
create_boxplot(employee, 'YearsSinceLastPromotion')
# Out:
# Median: 1.0
# IQR: 3.0

# %%
create_numerical_histogram(employee, 'YearsSinceLastPromotion', 8)
# Out:
# C:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# There is are several outliers. The outliers in this box plot represent individual cases where employees have gone an unusually long time since their last promotion, compared to the majority. While these cases are less common, they are not outside the realm of possibility. Therefore, it might be beneficial to keep these data points.

# %% [markdown]
# ##### Checking YearsWithCurrManager column

# %%
unique(employee, 'YearsWithCurrManager')
# Out:
# array([ 5,  7,  0,  2,  6,  8,  3, 11, 17,  1,  4, 12,  9, 10, 15, 13, 16,
#        14], dtype=int64)

# %%
create_boxplot(employee, 'YearsWithCurrManager')
# Out:
# Median: 3.0
# IQR: 5.0

# %%
create_numerical_histogram(employee, 'YearsWithCurrManager', 8)
# Out:
# C:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [raw]
# In this context, these outliers are not necessarily errors or incorrect data, but rather indicate less common occurrences. They represent individuals who are with there current manager for a long period of time. While these cases are less common, they are not outside the realm of possibility. Therefore, it might be beneficial to keep these data points.

# %%
employee.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                   object
# EducationField              object
# EmployeeNumber               int64
# EnvironmentSatisfaction     object
# Gender                      object
# HourlyRate                   int64
# JobInvolvement              object
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction             object
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating           object
# RelationshipSatisfaction    object
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# ...

# %%
numerical_columns = employee.select_dtypes(include=['int64', 'float64']).columns
categorical_columns = employee.select_dtypes(include=['object']).columns
one_hot_encoded_df = pd.get_dummies(employee[categorical_columns])
one_hot_encoded_columns = one_hot_encoded_df.columns
selected_columns = list(numerical_columns) + list(one_hot_encoded_columns)
employee_encoded = pd.concat([employee[numerical_columns], one_hot_encoded_df], axis=1)
correlation_matrix = employee_encoded[selected_columns].corr()
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                                          Age  DailyRate  DistanceFromHome  \
# Age                                 1.000000   0.010661         -0.001686
# DailyRate                           0.010661   1.000000         -0.004985
# DistanceFromHome                   -0.001686  -0.004985          1.000000
# EmployeeNumber                     -0.010145  -0.050990          0.032916
# HourlyRate                          0.024287   0.023381          0.031131
# ...                                      ...        ...               ...
# RelationshipSatisfaction_Very High  0.050024   0.019082          0.001628
# WorkLifeBalance_Bad                 0.009554   0.005718          0.006882
# WorkLifeBalance_Best               -0.013256  -0.031592         -0.038609
# WorkLifeBalance_Better             -0.010062  -0.012570          0.013079
# WorkLifeBalance_Good                0.016048   0.034220          0.009075
#
# ...

# %% [markdown]
# #### Univariate Analysis of Numerical Columns

# %%
summary_stats = employee.describe()

# Display the summary statistics
print(summary_stats)
# Out:
#                Age    DailyRate  DistanceFromHome  EmployeeNumber  \
# count  1470.000000  1470.000000       1470.000000     1470.000000
# mean     36.923810   802.485714          9.192517     1024.865306
# std       9.135373   403.509100          8.106864      602.024335
# min      18.000000   102.000000          1.000000        1.000000
# 25%      30.000000   465.000000          2.000000      491.250000
# 50%      36.000000   802.000000          7.000000     1020.500000
# 75%      43.000000  1157.000000         14.000000     1555.750000
# max      60.000000  1499.000000         29.000000     2068.000000
#
#         HourlyRate     JobLevel  MonthlyIncome   MonthlyRate  \
# count  1470.000000  1470.000000    1470.000000   1470.000000
# mean     65.891156     2.063946    6502.931293  14313.103401
# std      20.329428     1.106940    4707.956783   7117.786044
# min      30.000000     1.000000    1009.000000   2094.000000
# 25%      48.000000     1.000000    2911.000000   8047.000000
# ...

# %% [markdown]
# ##### Analyzing skewness and kurtosis for some major numerical columns

# %%
def calculate_skewness_and_kurtosis(df, column_name):

    sns.distplot(df[column_name])
    # Calculate skewness and kurtosis
    skewness = df[column_name].skew()
    kurt = df[column_name].kurt()
    
    print("Skewness:", skewness)
    print("Kurtosis:", kurt)

# %%
calculate_skewness_and_kurtosis(employee, 'MonthlyIncome')
# Out:
# Skewness: 1.3698166808390662
# Kurtosis: 1.005232691449859
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22772\3438909133.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column_name])
# C:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# The "Monthly Income" variable exhibits a positive skew, indicating a distribution skewed towards higher values with a longer tail on the right. Its negative kurtosis suggests a flatter distribution with lighter tails compared to a normal distribution.

# %%
calculate_skewness_and_kurtosis(employee, 'YearsAtCompany')
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22772\3438909133.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column_name])
# C:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Skewness: 1.7645294543422085
# Kurtosis: 3.93550875575465

# %% [markdown]
# The "YearsAtCompany" variable exhibits a positive skew, indicating a distribution skewed towards higher values with a longer tail on the right. Its positive kurtosis highlights heaver tails, and peaked distribution.

# %%
calculate_skewness_and_kurtosis(employee, 'Age')
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22772\3438909133.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column_name])
# C:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Skewness: 0.4132863018563338
# Kurtosis: -0.4041451371872906

# %% [markdown]
# The "Age" variable exhibits a kind of positive skew, indicating a distribution skewed towards higher values with a longer tail on the right. Its negative kurtosis suggests a flatter distribution with lighter tails compared to a normal distribution.

# %%
calculate_skewness_and_kurtosis(employee, 'DistanceFromHome')
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22772\3438909133.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column_name])
# C:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Skewness: 0.9581179956568269
# Kurtosis: -0.22483340490405102

# %% [markdown]
# The "DistanceFromHome" variable exhibits a positive skew, indicating a distribution skewed towards higher values with a longer tail on the right. Its negative kurtosis suggests a flatter distribution with lighter tails compared to a normal distribution.

# %%
calculate_skewness_and_kurtosis(employee, 'PercentSalaryHike')
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22772\3438909133.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column_name])
# C:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Skewness: 0.8211279755780908
# Kurtosis: -0.30059822209054543

# %% [markdown]
# The "PercentSalaryHike" variable exhibits a kind of positive skew, indicating a distribution skewed towards higher values with a longer tail on the right. Its negative kurtosis suggests a flatter distribution with lighter tails compared to a normal distribution.

# %% [markdown]
# #### Bivariate Analysis of Numerical Columns

# %%
import numpy as np

# Select only numerical columns for correlation analysis
numerical_cols = employee.select_dtypes(include=['int64', 'float64']).columns

# Calculate the correlation matrix
correlation_matrix = employee[numerical_cols].corr()

# Mask the upper triangle of the correlation matrix
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, mask=mask, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix of Numerical Variables')
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %% [markdown]
# JobLevel and MonthlyIncome:
# -There’s a very strong positive correlation of 0.95 between JobLevel and MonthlyIncome.
# -This suggests that as an employee’s job level increases, their monthly income tends to increase significantly.
#
# TotalWorkingYears and Several Variables:
# -TotalWorkingYears has strong positive correlations with JobLevel, MonthlyIncome, and YearsAtCompany.
# -This indicates that employees with more total working years tend to have higher job levels, higher income, and longer tenure at the company.
#
# Age and TotalWorkingYears:
# -A notable positive correlation exists between Age and TotalWorkingYears.
# -Older employees generally have more years of work experience.
#
# Negative Correlations:
# -There are some negative correlations present, though they are not as strong as the positive ones.
# -For example, NumCompaniesWorked might have a slight negative correlation with YearsAtCompany, suggesting that those who have worked at many companies don’t stay as long at one company.

# %% [markdown]
# #### Analysis of Categorical columns through anova, t-test and chi-square.

# %%
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

def perform_anova_tukey(dataframe, dependent_variable, independent_variable):
    
    # Replace category names in the DataFrame
    dataframe.columns = [col.replace(' ', '_').replace('%', '_percent') for col in dataframe.columns]

    # Fit OLS model
    formula = f'{dependent_variable} ~ C(Q("{independent_variable}"))'
    model = ols(formula, data=dataframe).fit()
    
    # Perform ANOVA
    anova_table = model.summary().tables[0]
    print("ANOVA Table:")
    print(anova_table)
    
    # Check ANOVA p-value
    p_value = model.f_pvalue
    
    # Perform Tukey's test if ANOVA p-value is less than 0.05
    print ("\np value: ", p_value, '\n')
    if p_value < 0.05:
        print(f"{dependent_variable} - {independent_variable}: We reject null hypothesis because p-value < 0.05 which implies that the mean values across each group are not equal.")

        tukey_results = pairwise_tukeyhsd(dataframe[dependent_variable], dataframe[independent_variable])
        print("\nTukey's Test Results:")
        print(tukey_results)
    else:
        print(f"{dependent_variable} - {independent_variable}: We fail to reject null hypothesis because p-value > 0.05 which implies that the mean values across each group are equal.")

# %%
from scipy.stats import ttest_ind

def perform_t_test(dataframe, group1, group2, dependent_variable, independent_variable):
    group1_data = dataframe[dataframe[independent_variable] == group1][dependent_variable]
    group2_data = dataframe[dataframe[independent_variable] == group2][dependent_variable]

    # Perform t-test
    t_statistic, p_value = ttest_ind(group1_data, group2_data)

    print(f"{independent_variable} - {group1} vs {group2} T-Test:")
    print(f"T-Statistic: {t_statistic}")
    print(f"P-Value: {p_value}")

    if p_value < 0.05:
        print(f"{dependent_variable} - {independent_variable}: We reject null hypothesis because p-value < 0.05 which implies that the mean values across each group are not equal.")
    else:
        print(f"{dependent_variable} - {independent_variable}: We fail to reject null hypothesis because p-value > 0.05 which implies that the mean values across each group are equal.")

# %%
from scipy.stats import chi2_contingency

def chi_square_test(df, column1, column2):
    # Count of occurrences of all combinations of the two columns
    data_crosstab = pd.crosstab(df[column1], df[column2], margins=False)
    print(data_crosstab)

    # Perform chi-square test
    stat, p, dof, expected = chi2_contingency(data_crosstab)
    print('Degrees of Freedom (dof) = %d' % dof)
    print('Expected frequencies:')
    print(expected)

    # Interpret p-value
    alpha = 0.05
    print('Significance level (alpha) = %.3f' % alpha)
    print('p-value = %.3f' % p)
    if p <= alpha:
        print(f"{column1} - {column2}: Dependent (reject H0): There is evidence that the two categorical variables are associated as p < 0.05.")
    else:
        print(f"{column1} - {column2}: Independent (fail to reject H0): There is no evidence that the two categorical variables are associated as p > 0.05.")

# %%
employee.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                   object
# EducationField              object
# EmployeeNumber               int64
# EnvironmentSatisfaction     object
# Gender                      object
# HourlyRate                   int64
# JobInvolvement              object
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction             object
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating           object
# RelationshipSatisfaction    object
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# ...

# %%
perform_t_test(employee, 'Yes', 'No', 'JobLevel', 'Attrition')
# Out:
# Attrition - Yes vs No T-Test:
# T-Statistic: -6.573837830953691
# P-Value: 6.795384780015254e-11
# JobLevel - Attrition: We reject null hypothesis because p-value < 0.05 which implies that the mean values across each group are not equal.

# %% [markdown]
# JobLevel - Attrition: We reject null hypothesis because p-value < 0.05 which implies that the mean values across each group are not equal.

# %%
perform_t_test(employee, 'Yes', 'No', 'Age', 'Attrition')
# Out:
# Attrition - Yes vs No T-Test:
# T-Statistic: -6.178663835307217
# P-Value: 8.356308021103587e-10
# Age - Attrition: We reject null hypothesis because p-value < 0.05 which implies that the mean values across each group are not equal.

# %% [markdown]
# Age - Attrition: We reject null hypothesis because p-value < 0.05 which implies that the mean values across each group are not equal.

# %%
perform_t_test(employee, 'Yes', 'No', 'YearsSinceLastPromotion', 'Attrition')
# Out:
# Attrition - Yes vs No T-Test:
# T-Statistic: -1.2657876620135298
# P-Value: 0.2057899591624936
# YearsSinceLastPromotion - Attrition: We fail to reject null hypothesis because p-value > 0.05 which implies that the mean values across each group are equal.

# %% [markdown]
# YearsSinceLastPromotion - Attrition: We fail to reject null hypothesis because p-value > 0.05 which implies that the mean values across each group are equal.

# %%
perform_t_test(employee, 'Yes', 'No', 'PercentSalaryHike', 'Attrition')
# Out:
# Attrition - Yes vs No T-Test:
# T-Statistic: -0.5164573250747643
# P-Value: 0.6056128238893757
# PercentSalaryHike - Attrition: We fail to reject null hypothesis because p-value > 0.05 which implies that the mean values across each group are equal.

# %% [markdown]
# PercentSalaryHike - Attrition: We fail to reject null hypothesis because p-value > 0.05 which implies that the mean values across each group are equal.

# %%
perform_t_test(employee, 'Yes', 'No', 'YearsAtCompany', 'Attrition')
# Out:
# Attrition - Yes vs No T-Test:
# T-Statistic: -5.1963086670254235
# P-Value: 2.3188716103863033e-07
# YearsAtCompany - Attrition: We reject null hypothesis because p-value < 0.05 which implies that the mean values across each group are not equal.

# %% [markdown]
# YearsAtCompany - Attrition: We reject null hypothesis because p-value < 0.05 which implies that the mean values across each group are not equal.

# %%
perform_anova_tukey(employee, 'MonthlyIncome', 'JobRole')
# Out:
# ANOVA Table:
#                             OLS Regression Results
# ...
# Dep. Variable:          MonthlyIncome   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.815
# Method:                 Least Squares   F-statistic:                     810.2
# Date:                Tue, 14 May 2024   Prob (F-statistic):               0.00
# Time:                        02:59:35   Log-Likelihood:                -13273.
# No. Observations:                1470   AIC:                         2.656e+04
# Df Residuals:                    1461   BIC:                         2.661e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#
# p value:  0.0
#
# MonthlyIncome - JobRole: We reject null hypothesis because p-value < 0.05 which implies that the mean values across each group are not equal.
#
# Tukey's Test Results:
#                        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...

# %% [markdown]
# MonthlyIncome - JobRole: We reject null hypothesis because p-value < 0.05 which implies that the mean values across each group are not equal.
# The four groups with most significant difference are:
# 1) Healthcare Representative and Laboratory Technician
# 2) Healthcare Representative and Sales Representative
# 3) Manufacturing Director and Sales Representative
# 4) Sales Executive and Sales Representative

# %%
perform_anova_tukey(employee, 'MonthlyRate', 'Education')
# Out:
# ANOVA Table:
#                             OLS Regression Results
# ...
# Dep. Variable:            MonthlyRate   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.8386
# Date:                Tue, 14 May 2024   Prob (F-statistic):              0.501
# Time:                        02:59:37   Log-Likelihood:                -15123.
# No. Observations:                1470   AIC:                         3.026e+04
# Df Residuals:                    1465   BIC:                         3.028e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#
# p value:  0.5006310641801303
#
# MonthlyRate - Education: We fail to reject null hypothesis because p-value > 0.05 which implies that the mean values across each group are equal.

# %% [markdown]
# MonthlyRate - Education: We fail to reject null hypothesis because p-value > 0.05 which implies that the mean values across each group are equal.

# %%
chi_square_test(employee, 'EducationField', 'JobRole')
# Out:
# JobRole           Healthcare Representative  Human Resources  \
# EducationField
# Human Resources                           0               21
# Life Sciences                            60               13
# Marketing                                 0                0
# Medical                                  48               11
# Other                                     9                3
# Technical Degree                         14                4
#
# JobRole           Laboratory Technician  Manager  Manufacturing Director  \
# EducationField
# Human Resources                       0        6                       0
# Life Sciences                       119       40                      71
# Marketing                             0       14                       0
# Medical                              99       32                      53
# Other                                22        5                       7
# ...

# %% [markdown]
# EducationField - JobRole: Dependent (reject H0): There is evidence that the two categorical variables are associated as p < 0.05.

# %%
chi_square_test(employee, 'Department', 'JobRole')
# Out:
# JobRole                 Healthcare Representative  Human Resources  \
# Department
# Human Resources                                 0               52
# Research & Development                        131                0
# Sales                                           0                0
#
# JobRole                 Laboratory Technician  Manager  \
# Department
# Human Resources                             0       11
# Research & Development                    259       54
# Sales                                       0       37
#
# JobRole                 Manufacturing Director  Research Director  \
# Department
# Human Resources                              0                  0
# Research & Development                     145                 80
# Sales                                        0                  0
#
# JobRole                 Research Scientist  Sales Executive  \
# Department
# Human Resources                          0                0
# ...

# %% [markdown]
# Department - JobRole: Dependent (reject H0): There is evidence that the two categorical variables are associated as p < 0.05.

# %%
chi_square_test(employee, 'Attrition', 'Department')
# Out:
# Department  Human Resources  Research & Development  Sales
# Attrition
# No                       51                     828    354
# Yes                      12                     133     92
# Degrees of Freedom (dof) = 2
# Expected frequencies:
# [[ 52.84285714 806.06326531 374.09387755]
#  [ 10.15714286 154.93673469  71.90612245]]
# Significance level (alpha) = 0.050
# p-value = 0.005
# Attrition - Department: Dependent (reject H0): There is evidence that the two categorical variables are associated as p < 0.05.

# %% [markdown]
# Attrition - Department: Dependent (reject H0): There is evidence that the two categorical variables are associated as p < 0.05.

# %%
chi_square_test(employee, 'Attrition', 'Gender')
# Out:
# Gender     Female  Male
# Attrition
# No            501   732
# Yes            87   150
# Degrees of Freedom (dof) = 1
# Expected frequencies:
# [[493.2 739.8]
#  [ 94.8 142.2]]
# Significance level (alpha) = 0.050
# p-value = 0.291
# Attrition - Gender: Independent (fail to reject H0): There is no evidence that the two categorical variables are associated as p > 0.05.

# %% [markdown]
# Attrition - Gender: Independent (fail to reject H0): There is no evidence that the two categorical variables are associated as p > 0.05.

# %%
chi_square_test(employee, 'Attrition', 'WorkLifeBalance')
# Out:
# WorkLifeBalance  Bad  Best  Better  Good
# Attrition
# No                55   126     766   286
# Yes               25    27     127    58
# Degrees of Freedom (dof) = 3
# Expected frequencies:
# [[ 67.10204082 128.33265306 749.02653061 288.53877551]
#  [ 12.89795918  24.66734694 143.97346939  55.46122449]]
# Significance level (alpha) = 0.050
# p-value = 0.001
# Attrition - WorkLifeBalance: Dependent (reject H0): There is evidence that the two categorical variables are associated as p < 0.05.

# %% [markdown]
# Attrition - WorkLifeBalance: Dependent (reject H0): There is evidence that the two categorical variables are associated as p < 0.05.

# %%
chi_square_test(employee, 'Attrition', 'JobRole')
# Out:
# JobRole    Healthcare Representative  Human Resources  Laboratory Technician  \
# Attrition
# No                               122               40                    197
# Yes                                9               12                     62
#
# JobRole    Manager  Manufacturing Director  Research Director  \
# Attrition
# No              97                     135                 78
# Yes              5                      10                  2
#
# JobRole    Research Scientist  Sales Executive  Sales Representative
# Attrition
# No                        245              269                    50
# Yes                        47               57                    33
# Degrees of Freedom (dof) = 8
# Expected frequencies:
# [[109.87959184  43.61632653 217.24285714  85.55510204 121.62244898
#    67.10204082 244.92244898 273.44081633  69.61836735]
#  [ 21.12040816   8.38367347  41.75714286  16.44489796  23.37755102
#    12.89795918  47.07755102  52.55918367  13.38163265]]
# ...

# %% [markdown]
# Attrition - JobRole: Dependent (reject H0): There is evidence that the two categorical variables are associated as p < 0.05.

# %%
chi_square_test(employee, 'Attrition', 'EnvironmentSatisfaction')
# Out:
# EnvironmentSatisfaction  High  Low  Medium  Very High
# Attrition
# No                        391  212     244        386
# Yes                        62   72      43         60
# Degrees of Freedom (dof) = 3
# Expected frequencies:
# [[379.96530612 238.2122449  240.72857143 374.09387755]
#  [ 73.03469388  45.7877551   46.27142857  71.90612245]]
# Significance level (alpha) = 0.050
# p-value = 0.000
# Attrition - EnvironmentSatisfaction: Dependent (reject H0): There is evidence that the two categorical variables are associated as p < 0.05.

# %% [markdown]
# Attrition - EnvironmentSatisfaction: Dependent (reject H0): There is evidence that the two categorical variables are associated as p < 0.05.

# %%
chi_square_test(employee, 'MaritalStatus', 'RelationshipSatisfaction')
# Out:
# RelationshipSatisfaction  High  Low  Medium  Very High
# MaritalStatus
# Divorced                   111   52      75         89
# Married                    204  141     137        191
# Single                     144   83      91        152
# Degrees of Freedom (dof) = 6
# Expected frequencies:
# [[102.10408163  61.39591837  67.40204082  96.09795918]
#  [210.14081633 126.35918367 138.72040816 197.77959184]
#  [146.75510204  88.24489796  96.87755102 138.12244898]]
# Significance level (alpha) = 0.050
# p-value = 0.250
# MaritalStatus - RelationshipSatisfaction: Independent (fail to reject H0): There is no evidence that the two categorical variables are associated as p > 0.05.

# %% [markdown]
# MaritalStatus - RelationshipSatisfaction: Independent (fail to reject H0): There is no evidence that the two categorical variables are associated as p > 0.05.

# %%
# Output the clean dataset
clean_file_path = "clean_data.csv"
employee.to_csv(clean_file_path, index=False)

# Print a message indicating the file path where the clean dataset is saved
print("Clean dataset saved to:", clean_file_path)
# Out:
# Clean dataset saved to: clean_data.csv
